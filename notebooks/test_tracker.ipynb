# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
sys.path.append("C:\\users\\snjvs\\pycharmprojects\\golfswing")
from golfswing.camera import camera
from golfswing.graph2d import line, screen, line_style
from golfswing.graph2d import draw
from golfswing.graph2d import parallelogram

# %%
from golfswing.algorithms import tracker

# %%
# Read video
video = cv2.VideoCapture("../data/test1.mp4")

# Exit if video not opened.
if not video.isOpened():
    sys.exit()

# %%
ok, frame = video.read()
if not ok:
    print('Cannot read video file')
    sys.exit()

# %%
plt.imshow(frame)

# %%
bbox = (200, 300, 100, 100)

# %%
t1 = tracker.Tracker()

# %%
t1.add(frame, bbox)

# %%
ok, frame = video.read()

# %%
boxes = t1.update(frame)

# %%
print(boxes)
# Out:
# [(194, 290, 100, 100)]

# %%
cv2.rectangle(frame, 194, 290, 100, 100)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36520\3852623734.py in <module>
# ----> 1 cv2.rectangle(frame, 194, 290, 100, 100)
#
# error: OpenCV(4.5.5) :-1: error: (-5:Bad argument) in function 'rectangle'
# > Overload resolution failed:
# >  - Can't parse 'pt1'. Input argument doesn't provide sequence protocol
# >  - Can't parse 'pt1'. Input argument doesn't provide sequence protocol
# >  - Can't parse 'rec'. Input argument doesn't provide sequence protocol
# >  - Can't parse 'rec'. Input argument doesn't provide sequence protocol
