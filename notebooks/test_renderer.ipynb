# %%
import cv2
import numpy as np
import sys
sys.path.append("C:\\users\\snjvs\\pycharmprojects\\golfswing")
from golfswing.graph2d import screen
from golfswing.algorithms import render, fpu
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32504\1977820015.py in <module>
#       4 sys.path.append("C:\\users\\snjvs\\pycharmprojects\\golfswing")
#       5 from golfswing.graph2d import screen
# ----> 6 from golfswing.algorithms import render, fpu
#
# C:\users\snjvs\pycharmprojects\golfswing\golfswing\algorithms\fpu.py in <module>
#       4 """
#       5
# ----> 6 from golfswing.algorithms import tracker
#       7 from golfswing.graph2d import utils, parallelogram
#       8
#
# C:\users\snjvs\pycharmprojects\golfswing\golfswing\algorithms\tracker.py in <module>
#       1 import cv2
#       2
# ----> 3 class Tracker:
#       4     # OpenCV object tracker implementations
#       5     OPENCV_OBJECT_TRACKERS = {
#
# C:\users\snjvs\pycharmprojects\golfswing\golfswing\algorithms\tracker.py in Tracker()
# ...

# %%
img =np.zeros(shape=(800, 1280, 3), dtype=np.uint8)
np.nonzero(img)
# Out:
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))

# %%
hints = {}
hints["led0"] = (100, 200)
hints["led1"] = (150, 250)
hints["init_ball"] = (400, 500)
hints["swing_plane_pt0"] = (20, 30)
hints["swing_plane_pt1"] = (30, 40)
hints["swing_plane_pt2"] = (40, 50)

# %%
f1 = fpu.Fpu

# %%
render.render(img, screen_desc)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img)
img.any()
# Out:
# True

# %%
print(img[20][10][1])
# Out:
# 0

# %%
for x in range(1200):
    for y in range(800):
        color = img[y, x]
        if color[2] == 255:
            print(f"x={x},y={y},img={color}")
# Out:
# x=8,y=16,img=[  0 255 255]
# x=8,y=23,img=[  0 255 255]
# x=8,y=30,img=[  0 255 255]
# x=8,y=37,img=[  0 255 255]
# x=8,y=44,img=[  0 255 255]
# x=8,y=51,img=[  0 255 255]
# x=8,y=58,img=[  0 255 255]
# x=8,y=65,img=[  0 255 255]
# x=8,y=72,img=[  0 255 255]
# x=8,y=79,img=[  0 255 255]
# x=8,y=86,img=[  0 255 255]
# x=8,y=93,img=[  0 255 255]
# x=8,y=100,img=[  0 255 255]
# x=8,y=107,img=[  0 255 255]
# x=8,y=114,img=[  0 255 255]
# x=8,y=121,img=[  0 255 255]
# x=8,y=128,img=[  0 255 255]
# x=8,y=135,img=[  0 255 255]
# x=8,y=142,img=[  0 255 255]
# x=8,y=149,img=[  0 255 255]
# x=8,y=156,img=[  0 255 255]
# x=8,y=163,img=[  0 255 255]
# x=8,y=170,img=[  0 255 255]
# x=8,y=177,img=[  0 255 255]
# x=8,y=184,img=[  0 255 255]
# x=8,y=191,img=[  0 255 255]
# x=8,y=198,img=[  0 255 255]
# x=8,y=205,img=[  0 255 255]
# x=8,y=212,img=[  0 255 255]
# x=8,y=219,img=[  0 255 255]
# x=8,y=226,img=[  0 255 255]
# x=8,y=233,img=[  0 255 255]
# x=8,y=240,img=[  0 255 255]
# ...

# %%
img[10, 100]
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
img[100][500]
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
np.nonzero(img)
# Out:
# (array([  4,   4,   5, ..., 799, 799, 799], dtype=int64),
#  array([  0,   0,   0, ...,   0, 100, 100], dtype=int64),
#  array([1, 2, 1, ..., 2, 1, 2], dtype=int64))

# %%
img[4][4]
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
img[100, 500]
# Out:
# array([0, 0, 0], dtype=uint8)
